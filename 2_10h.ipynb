# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Dense, Flatten
from tensorflow.keras import activations
from keras.preprocessing.image import ImageDataGenerator

path = '/content/drive/MyDrive/3-1 proj/NNFL assignment2/Images'

data = ImageDataGenerator(rescale=1./255, validation_split=0.3)
train_images = data.flow_from_directory(path, target_size=(128, 128), class_mode='categorical', subset = 'training')
test_images = data.flow_from_directory(path, target_size=(128, 128), class_mode='categorical', subset = 'validation')

model = Sequential()

model.add(Conv2D(filters = 8, kernel_size = 3, input_shape=(128, 128, 3), padding = "same"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(filters = 16, kernel_size = 3, padding = "same"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(filters = 32, kernel_size = 3, padding = "same"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(filters = 64, kernel_size = 3, padding = "same"))
model.add(Flatten())

model.add(Dense(128))
model.add(Activation('relu'))

model.add(Dense(64))
model.add(Dropout(0.3))
model.add(Activation('relu'))

model.add(Dense(32))
model.add(Activation('relu'))

model.add(Dense(16))
model.add(Dropout(0.3))
model.add(Activation('relu'))

model.add(Dense(3))
model.add(Activation('softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images, epochs = 25, batch_size = 4, validation_data=test_images)

print("Overall accuracy(in %): " + str(history.history['accuracy'][-1]*100))
print("Validation accuracy(in %): " + str(history.history['val_accuracy'][-1]*100))
# Out:
# Found 505 images belonging to 3 classes.
# Found 215 images belonging to 3 classes.
# Epoch 1/25
# 16/16 [==============================] - 74s 5s/step - loss: 6.0253 - accuracy: 0.3089 - val_loss: 1.2141 - val_accuracy: 0.3209
# Epoch 2/25
# 16/16 [==============================] - 71s 4s/step - loss: 1.2953 - accuracy: 0.3188 - val_loss: 1.1687 - val_accuracy: 0.3209
# Epoch 3/25
# 16/16 [==============================] - 73s 5s/step - loss: 1.0956 - accuracy: 0.4337 - val_loss: 1.0581 - val_accuracy: 0.2791
# Epoch 4/25
# 16/16 [==============================] - 72s 4s/step - loss: 0.9471 - accuracy: 0.4950 - val_loss: 0.8619 - val_accuracy: 0.7767
# Epoch 5/25
# 16/16 [==============================] - 71s 4s/step - loss: 0.8109 - accuracy: 0.5822 - val_loss: 0.6356 - val_accuracy: 0.8930
# Epoch 6/25
# 16/16 [==============================] - 71s 4s/step - loss: 0.6388 - accuracy: 0.7347 - val_loss: 0.4439 - val_accuracy: 0.9023
# Epoch 7/25
# ...
